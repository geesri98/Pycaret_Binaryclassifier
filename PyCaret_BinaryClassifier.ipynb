# %%
import pandas as pd
import numpy as np
from numpy import argmax

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os
os.environ["GIT_PYTHON_REFRESH"] = "quiet"
import git

from sklearn import model_selection, metrics
from sklearn.metrics import recall_score, precision_score, roc_auc_score, accuracy_score, f1_score, matthews_corrcoef, brier_score_loss, classification_report, confusion_matrix

# %%
df = pd.read_csv(r"C:\Users\vegek\OneDrive\Documents\DS-Reference\Python Scripts\pima-indians-diabetes.csv")

# %%
df2 = df.copy()

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.5'

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from numpy import argmax
from numpy import sqrt

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from pycaret.classification import *

# %%
df2.columns.values
# Out:
# array(['Preg', 'Plas', 'Pres', 'skin', 'test', 'mass', 'pedi', 'age',
#        'class'], dtype=object)

# %%
clf1 = setup(df2, target='class', session_id=123, log_experiment = True, experiment_name='Exp1_Pycaret_BinaryClassifier')
# Out:
# <style type="text/css">
# #T_26ed8_row19_col1, #T_26ed8_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_26ed8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26ed8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26ed8_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_26ed8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_26ed8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26ed8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_26ed8_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_26ed8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_a752f_ th {
#   text-align: left;
# }
# ...
